# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('jsrt_metadata.csv', header=None)

# %%
df
# Out:
#                 0         1     2    3       4     5     6           7  \
# 0        study_id  subtlety  size  age  gender     x     y       state
# 1    JPCLN001.png         5    15   53    Male  1634   692   malignant
# 2    JPCLN002.png         5    30   78  Female  1614  1090      benign
# 3    JPCLN003.png         5    30   63  Female  1303   447   malignant
# 4    JPCLN004.png         5    14   68  Female   606   836      benign
# ..            ...       ...   ...  ...     ...   ...   ...         ...
# 243  JPCNN089.png       NaN   NaN   50    Male   NaN   NaN  non-nodule
# 244  JPCNN090.png       NaN   NaN   68  Female   NaN   NaN  non-nodule
# 245  JPCNN091.png       NaN   NaN   81    Male   NaN   NaN  non-nodule
# 246  JPCNN092.png       NaN   NaN   70  Female   NaN   NaN  non-nodule
# 247  JPCNN093.png       NaN   NaN   41    Male   NaN   NaN  non-nodule
#
#                       8                   9
# 0              position           diagnosis
# ...

# %%
X = df.iloc[:,9]

# %%
size = len(X) - X.isnull().sum() -1

# %%
X = df.iloc[1:size,9]

# %%
X
# Out:
# 1                       lung cancer
# 2                pulmonary hematoma
# 3                       lung cancer
# 4                 Inflammatory mass
# 5                       lung cancer
#                    ...
# 149                       hamartoma
# 150     lung cancer(adenocarcinoma)
# 151    metastasis of uterine cancer
# 152                 susp. hamartoma
# 153                     lung cancer
# Name: 9, Length: 153, dtype: object

# %%
Y = X.unique()

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 100}


plt.rc('font', **font)

fig, ax = plt.subplots(figsize =(300, 120))
ax.hist(X, Y)

rects = ax.patches
labels = [Y[i] for i in range(len(rects))]
  
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height+0.01, label,
            ha='center', va='bottom')

plt.show()

# %%
z = list()
for p in range(1,size):
    z.append(X[p])

dic = dict()
for word in z:
    if word in dic:
        dic[word] = dic[word]+1
    else:
        dic[word] = 1
dic
# Out:
# {'lung cancer': 56,
#  'pulmonary hematoma': 2,
#  'Inflammatory mass': 2,
#  'tuberculoma': 14,
#  'granuloma': 8,
#  'lung cancer(adenocarcinoma)': 23,
#  'hamartoma': 2,
#  'unknown': 4,
#  'lung abscess': 2,
#  'lung cancer(bronchioloalveolar cell carcinoma)': 7,
#  'Cryptococcosis': 2,
#  'lung cancer(squamous cell carcinoma)': 2,
#  'susp. sclerosing hemangioma': 1,
#  'pulmonary tuberculosis': 3,
#  'metastasis of colon cancer': 4,
#  'organiging pneumonia': 1,
#  'inflammatory mass': 4,
#  'susp.tuberculoma': 1,
#  'susp. inflammatory mass': 2,
#  'lung cancer(small cell carcinoma)': 1,
#  'lung canceror metastasis': 1,
#  'lung cancer(adenosquamous carcinoma)': 1,
#  'calcified granuloma': 1,
#  'pneumonia': 1,
#  'lung cancer(large cell carcinoma)': 1,
#  'metastatic lung cancer': 1,
#  'sclerosing hemangioma': 2,
#  'metastasis of ovarian cancer': 1,
#  'organizing pneumonia': 1,
#  'metastasis of uterine cancer': 1,
#  'susp. hamartoma': 1}

# %%
font = {'family' : 'normal',
        'size'   : 10}


plt.rc('font', **font)

fig = plt.figure(figsize =(35, 18))
plt.pie(dic.values(), labels = dic.keys())
plt.legend(title = "Diseases: ")
plt.show()

# %%
Z = df.iloc[1:size,7]

# %%
a = list()
for p in range(1,len(Z)):
    a.append(Z[p])
    
dic1 = dict()
for word in a:
    if word in dic1:
        dic1[word] = dic1[word]+1
    else:
        dic1[word] = 1

dic1
# Out:
# {'malignant': 98, 'benign': 54}

# %%
font = {'family' : 'normal',
        'size'   : 10}


plt.rc('font', **font)

fig = plt.figure(figsize =(10, 8))
plt.pie(dic1.values(), labels = dic1.keys())
plt.legend(title = "Diseases State: ")
plt.show()

# %%
K = df.iloc[1:size,4]

# %%
c = list()
for p in range(1,len(K)):
    c.append(K[p])

dic2 = dict()
for word in c:
    if word in dic2:
        dic2[word] = dic2[word]+1
    else:
        dic2[word] = 1
        
dic2
# Out:
# {'Male': 67, 'Female': 85}

# %%
font = {'family' : 'normal',
        'size'   : 10}


plt.rc('font', **font)

fig = plt.figure(figsize =(10, 8))
plt.pie(dic2.values(), labels = dic2.keys())
plt.legend(title = "Diseases With Respect To Gender: ")
plt.show()
